# %%
import pdb
def h(n):
    print('Start h')
    print(1/n)
    print(n)
def g(n):
    print('Start g')
    h(n-1)
    print(n)
def f(n):
    print('Start f')
    g(n-1)
    print(n)
pdb.run('f(2)')

# %%
import pdb
def arithmetic(numList):
    if len(numList)<2:
        return True
    diff = numList[1]-numList[0]
    for i in range(len(numList)):
        if numList[i+1]-numList[i] != diff:
            return False
        return True
pdb.run('arithmetic([2,4,6,8])')

# %%
import pdb
def arithmetic(numList):
    if len(numList)<2:
        return True
    diff = numList[1]-numList[0]
    for i in range(len(numList)):
        if numList[i+1]-numList[i] != diff:
            return False
        return True
pdb.run('arithmetic([2,4,6,8])')

# %%
import pdb
def arithmetic(numList):
    if len(numList)<2:
        return True
    diff = numList[1]-numList[0]
    for i in range(len(numList)):
        if numList[i+1]-numList[i] != diff:
            return False
    return True
pdb.run('arithmetic([2,4,6,8])')

# %%
import pdb
def slopes(points):
    for i in range(1, len(points)):
        x1, y1 = points[i-1]
        x2, y2 = points[i]
        slope = (y2-y1)/(x2-x1)
points = [(2,3), (5,6),(4,5), (4,3), (2,5), (9,4), (7,4), (3,7), (6,8), (8,5), (2,9)]

pdb.run('slopes(points)')
# Out:
# > <string>(1)<module>()
#
# ipdb> cl
# Clear all breaks? yes
# ipdb> b slopes
# Breakpoint 1 at <ipython-input-1-7ab522034de1>:2
# ipdb> c
# > <ipython-input-1-7ab522034de1>(3)slopes()
#       1 import pdb
# 1     2 def slopes(points):
# ----> 3     for i in range(1, len(points)):
#       4         x1, y1 = points[i-1]
#       5         x2, y2 = points[i]
#
# ipdb> b 6
# Breakpoint 2 at <ipython-input-1-7ab522034de1>:6
# ipdb> condition 2 x2-x1==0
# New condition set for breakpoint 2.
# ipdb> c
# > <ipython-input-1-7ab522034de1>(3)slopes()
#       1 import pdb
# 1     2 def slopes(points):
# ----> 3     for i in range(1, len(points)):
#       4         x1, y1 = points[i-1]
#       5         x2, y2 = points[i]
#
# ipdb> p i
# 1
# ipdb> p x1
# 2
# ipdb> p x2
# 5
# ipdb> c
# > <ipython-input-1-7ab522034de1>(3)slopes()
#       1 import pdb
# 1     2 def slopes(points):
# ----> 3     for i in range(1, len(points)):
#       4         x1, y1 = points[i-1]
#       5         x2, y2 = points[i]
#
# ipdb> p i
# 2
# ipdb> b
# Num Type         Disp Enb   Where
# 1   breakpoint   keep yes   at <ipython-input-1-7ab522034de1>:2
# 	breakpoint already hit 3 times
# 2   breakpoint   keep yes   at <ipython-input-1-7ab522034de1>:6
# 	stop only if x2-x1==0
# 	breakpoint already hit 2 times
# ipdb> n
# > <ipython-input-1-7ab522034de1>(4)slopes()
# 1     2 def slopes(points):
#       3     for i in range(1, len(points)):
# ----> 4         x1, y1 = points[i-1]
#       5         x2, y2 = points[i]
# 2     6         slope = (y2-y1)/(x2-x1)
#
# ipdb> c
# > <ipython-input-1-7ab522034de1>(6)slopes()
#       4         x1, y1 = points[i-1]
#       5         x2, y2 = points[i]
# 2---> 6         slope = (y2-y1)/(x2-x1)
#       7 points = [(2,3), (5,6),(4,5), (4,3), (2,5), (9,4), (7,4), (3,7), (6,8), (8,5), (2,9)]
#       8
#
# ipdb> p i
# 3
# ipdb> q

# %%
from random import randrange, seed
from platform import node
import pdb
def blackbox():
    seed(node())
    secret = randrange(10**5, 10**6)
    
    try:
        key = int(input('Enter key:'))
        if key != secret:
            print('failed')
        else:
            print('success!')
    except:
        print('failed')

pdb.run('blackbox()')
# Out:
# > <string>(1)<module>()
#
# ipdb> b 8
# End of file
# ipdb> b blackbox
# Breakpoint 3 at <ipython-input-3-0c2416d6cab6>:4
# ipdb> c
# > <ipython-input-3-0c2416d6cab6>(5)blackbox()
#       3 import pdb
# 3     4 def blackbox():
# ----> 5     seed(node())
#       6     secret = randrange(10**5, 10**6)
#       7
#
# ipdb> n
# > <ipython-input-3-0c2416d6cab6>(6)blackbox()
# 3     4 def blackbox():
#       5     seed(node())
# ----> 6     secret = randrange(10**5, 10**6)
#       7
#       8     try:
#
# ipdb> n
# > <ipython-input-3-0c2416d6cab6>(8)blackbox()
#       6     secret = randrange(10**5, 10**6)
#       7
# ----> 8     try:
#       9         key = int(input('Enter key:'))
#      10         if key != secret:
#
# ipdb> p secret
# 192553
# ipdb> c
# Enter key:192553
# success!
