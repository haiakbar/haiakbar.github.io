# %%
print(Hello World")
# Out:
#   File "<ipython-input-1-10cb182148e3>", line 1
#     print(Hello World)
#                 ^
# SyntaxError: invalid syntax

# %%
print("Hello World")
# Out:
# Hello World

# %%
x = input('enter: ')
print(x)
# Out:
# enter: 3
# 3

# %% [raw]
# %run pkgtest.py

# %%
# %run pkgtest.py

# %%
import math
math.sqrt(2);

# %%
import math
print(math.sqrt(2))
# Out:
# 1.4142135623730951

# %%
x = -7 -6 -5 -4 -3 -2 -1
print(x)
# Out:
# -28

# %%
x = 17*9+24*10+21*11+27*12
y = 17+24+21+27
z = x/y
print(z)
# Out:
# 10.651685393258427

# %%
print(2**-20)
# Out:
# 9.5367431640625e-07

# %%
print(4356//61)
# Out:
# 71

# %%
print(4356%61)
# Out:
# 25

# %%
s1 = '-'
s2 = '+'
a = s1 + s2
b = s1 + s2 + s1
c = s2 + s1 + s1
d = 2*(s2+s1+s1)
print(a)
print(b)
print(c)
print(d)
# Out:
# -+
# -+-
# +--
# +--+--

# %%
s1 = '-'
s2 = '+'
e = 10*(s2+s1+s1)+s2
print(e)
# Out:
# +--+--+--+--+--+--+--+--+--+--+

# %%
s=abcdefghijklmnopqrstuvwxyz
print(s.index[a])
print(s.index[c])
print(s.index[z])
print(s.index[y])
print(s.index[q])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-11093cfe2c02> in <module>
# ----> 1 s=abcdefghijklmnopqrstuvwxyz
#       2 print(s.index[a])
#       3 print(s.index[c])
#       4 print(s.index[z])
#       5 print(s.index[y])
#
# NameError: name 'abcdefghijklmnopqrstuvwxyz' is not defined

# %%
s = abcdefghijklmnopqrstuvwxyz
print(s.index[a])
print(s.index[c])
print(s.index[z])
print(s.index[y])
print(s.index[q])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-26e4652e2a56> in <module>
# ----> 1 s = abcdefghijklmnopqrstuvwxyz
#       2 print(s.index[a])
#       3 print(s.index[c])
#       4 print(s.index[z])
#       5 print(s.index[y])
#
# NameError: name 'abcdefghijklmnopqrstuvwxyz' is not defined

# %%
s = 'abcdefghijklmnopqrstuvwxyz'
print(s.index[a])
print(s.index[c])
print(s.index[z])
print(s.index[y])
print(s.index[q])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-294057804246> in <module>
#       1 s = 'abcdefghijklmnopqrstuvwxyz'
# ----> 2 print(s.index[a])
#       3 print(s.index[c])
#       4 print(s.index[z])
#       5 print(s.index[y])
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
s = 'abcdefghijklmnopqrstuvwxyz'
print(s.index(a))
print(s.index(c))
print(s.index(z))
print(s.index(y))
print(s.index(q))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-718de062e858> in <module>
# ----> 1 s = abcdefghijklmnopqrstuvwxyz
#       2 print(s.index(a))
#       3 print(s.index(c))
#       4 print(s.index(z))
#       5 print(s.index(y))
#
# NameError: name 'abcdefghijklmnopqrstuvwxyz' is not defined

# %%
s = 'abcdefghijklmnopqrstuvwxyz'
print(s.index(a))
print(s.index(c))
print(s.index(z))
print(s.index(y))
print(s.index(q))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-cc506753f2ae> in <module>
#       1 s = 'abcdefghijklmnopqrstuvwxyz'
# ----> 2 print(s.index(a))
#       3 print(s.index(c))
#       4 print(s.index(z))
#       5 print(s.index(y))
#
# ValueError: substring not found

# %%
s = 'abcdefghijklmnopqrstuvwxyz'
print(s.index('a'))
# Out:
# 0

# %%
s = 'abcdefghijklmnopqrstuvwxyz'
print(s.index('a'))
print(s.index('c'))
print(s.index('z'))
print(s.index('y'))
print(s.index('q'))
# Out:
# 0
# 2
# 25
# 24
# 16

# %%
s = 'goodbye'
print(s[0])
# Out:
# g

# %%
s = 'goodbye'
print(s[0]=='g')
# Out:
# True

# %%
s = 'goodbye'
print(s[0]=='g')
print(s[6]=='g')
print(s[0]+s[1]=='ga')
# Out:
# True
# False
# False

# %%
s = 'goodbye'
print(s[0]=='g')
print(s[6]=='g')
print(s[0]+s[1]=='ga')
print(s[-2]=='s')
print(s[3]=='d')
print(s[0]==s[-1])
print(s[-4]+s[-3]+s[-2]+[s-1]=='tion')
# Out:
# True
# False
# False
# False
# True
# False
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-1a56d370b2ba> in <module>
#       6 print(s[3]=='d')
#       7 print(s[0]==s[-1])
# ----> 8 print(s[-4]+s[-3]+s[-2]+[s-1]=='tion')
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %%
s = 'goodbye'
print(s[0]=='g')
print(s[6]=='g')
print(s[0]+s[1]=='ga')
print(s[-2]=='s')
print(s[3]=='d')
print(s[0]==s[-1])
print(s[-4]+s[-3]+s[-2]+s[-1]=='tion')
# Out:
# True
# False
# False
# False
# True
# False
# False

# %%
x = 'anachronistically'
y = 'counterintuitive'
z = len(x) == len(y)+1
print(z)
# Out:
# True

# %%
x = ('misinterpretation', 'misrepresentation')
x.sort()
y = 'misinterpretation' == x[0]
print(y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-1450df9f9bed> in <module>
#       1 x = ('misinterpretation', 'misrepresentation')
# ----> 2 x.sort()
#       3 y = 'misinterpretation' == x[0]
#       4 print(y)
#
# AttributeError: 'tuple' object has no attribute 'sort'

# %%
x = ['misinterpretation', 'misrepresentation']
x.sort()
y = 'misinterpretation' == x[0]
print(y)
# Out:
# True

# %%
x = 'abc'
print(x.index(e))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-9e551b1e33c6> in <module>
#       1 x = 'abc'
# ----> 2 print(x.index(e))
#
# ValueError: substring not found

# %%
x = 'floccinaucinihilipilification'
print(e in x)
# Out:
# False

# %%
a = 'counterrevolution'
b = 'counter'
c = 'resolution'
x = len(a)==len(b)+len(c)
print(x)
# Out:
# True

# %%
import turtle

# %%
a = 6
b = 7
c = (a+b)/2
inventory = ['paper', 'staples', 'pencils']
first = 'John'
middle = 'Fitzgerald'
last = 'Kennedy'
fullname = first + ' ' + middle + ' ' +last
print(fullname)
print(c)
print(inventory)
# Out:
# JohnFitzgeraldKennedy
# 6.5
# ['paper', 'staples', 'pencils']

# %%
a = 6
b = 7
c = (a+b)/2
inventory = ['paper', 'staples', 'pencils']
first = 'John'
middle = 'Fitzgerald'
last = 'Kennedy'
fullname = first + ' ' + middle + ' ' +last
print(fullname)
print(c)
print(inventory)
# Out:
# John Fitzgerald Kennedy
# 6.5
# ['paper', 'staples', 'pencils']

# %%
x = 17 - 9 < 10
print(x)
# Out:
# True

# %%
inventory = ['paper', 'staples', 'pencils']
print(len(inventory)
# Out:
#   File "<ipython-input-4-0a13e3b927bf>", line 2
#     print(len(inventory)
#                         ^
# SyntaxError: unexpected EOF while parsing

# %%
inventory = ['paper', 'staples', 'pencils']
print(len(inventory))
# Out:
# 3

# %%
inventory = ['paper', 'staples', 'pencils']
first = 'John'
middle = 'Fitzgerald'
last = 'Kennedy'
fullname = first + ' ' + middle + ' ' +last
x = len(inventory) > 5*len(fullname)
print(x)
# Out:
# False

# %%
a = 6
b = 7
c = (a+b)/2
x = c <= 24
print(x)
# Out:
# True

# %%
a = 6
b = 7
c = 6.75
x = c > a
y = c < b
print (x and y)
# Out:
# True

# %%
first = 'John'
middle = 'Fitzgerald'
last = 'Kennedy'
fullname = first + ' ' + middle + ' ' +last
x = len(middle) > len(first)
y = len(middle) < len (last)
print(x and y)
# Out:
# False

# %%
inventory = ['paper', 'staples', 'pencils']
x = len(inventory) == 0
y = len(inventory) > 10
print(x or y)
# Out:
# False

# %%
flowers = ('potato', 'bougainvillea', 'yucca', 'marigold', ' daylilly', 'lilly of the valley')
x = !('potato' in flowers)
print(x)
# Out:
# ['/bin/bash: potato: command not found']

# %%
flowers = ('potato', 'bougainvillea', 'yucca', 'marigold', ' daylilly', 'lilly of the valley')
x = 'potato' in flowers
print(x)
# Out:
# True

# %%
flowers = ['potato', 'bougainvillea', 'yucca', 'marigold', ' daylilly', 'lilly of the valley']
thorny = []
thorny.append(flowers[0])
thorny.append(flowers[1])
thorny.append(flowers[2])
print(thorny)
# Out:
# ['potato', 'bougainvillea', 'yucca']

# %%
flowers = ['potato', 'bougainvillea', 'yucca', 'marigold', ' daylilly', 'lilly of the valley']
thorny = []
thorny.append(flowers[0])
thorny.append(flowers[1])
thorny.append(flowers[2])
poisonous = []
poisonous.append(flowers[-1])
print(poisonous)
# Out:
# ['lilly of the valley']

# %%
flowers = ['potato', 'bougainvillea', 'yucca', 'marigold', ' daylilly', 'lilly of the valley']
thorny = []
thorny.append(flowers[0])
thorny.append(flowers[1])
thorny.append(flowers[2])
poisonous = []
poisonous.append(flowers[-1])
dangerous = thorny + poisonous
print(dangerous)
# Out:
# ['potato', 'bougainvillea', 'yucca', 'lilly of the valley']

# %%
answers = ['Y', 'Y', 'N', 'N', 'N', 'Y', 'N', 'N', 'Y', 'N', 'N', 'Y', 'N' ]
numYes = answers.count('Y')
print(numYes)
# Out:
# 5

# %%
answers = ['N', 'Y', 'N', 'N', 'N', 'Y', 'N', 'N', 'Y', 'N', 'N', 'Y', 'N' ]
numYes = answers.count('Y')
numNo = answers.count('N')
percentYes = str((numYes/(numYes + numNo))*100) + 'percent'
print(percentYes)
answers.sort()
print(answers.index('Y'))
# Out:
# 30.76923076923077percent
# 9

# %%
s = 'top'
x = s.reverse()
print(x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-ef3512df530f> in <module>
#       1 s = 'top'
# ----> 2 x = s.reverse()
#       3 print(x)
#
# AttributeError: 'str' object has no attribute 'reverse'

# %%
s = 'top'
print(s[1])
# Out:
# o

# %%
s = 'top'
x = s[0]
y = s[1]
z = s[2]
s = s[0]+s[1]+s[2]
print(x)
# Out:
# t

# %%
s = 'top'
x = s[0]
y = s[1]
z = s[2]
s = s[2]+s[1]+s[0]
print(s)
# Out:
# pot

# %%
s = 'Ljubomir'
t = 'Perkovic'
inisial = s[0] + t[0]
print(inisial)
# Out:
# LP

# %%
lst = [3, 7, -2, 12]
lst.sort()
range = lst[-1]-lst[0]
print(range)
# Out:
# 14

# %%
import turtle
s = turtle.Screen()
t = turtle.Turtle(shape='turtle')
t.penup()
t.goto(-300, 0)
t.pendown()

# %%
bye()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-5bde8bdb68d9> in <module>
# ----> 1 bye()
#
# NameError: name 'bye' is not defined

# %%
turtle.bye()

# %%
monthsL = ['Jan', 'Feb', 'Mar', 'May']
monthsT = ('Jan', 'Feb', 'Mar', 'May')
monthsL.insert(2, 'Apr')
monthsL.append('Jun')
print(monthsL)
monthsL.pop()
print(monthsL)
monthsL.pop(1)
print(monthsL)
monthsL.reverse()
print(monthsL)
# Out:
# ['Jan', 'Feb', 'Apr', 'Mar', 'May', 'Jun']
# ['Jan', 'Feb', 'Apr', 'Mar', 'May']
# ['Jan', 'Apr', 'Mar', 'May']
# ['May', 'Mar', 'Apr', 'Jan']

# %%
grades = ('B', 'B', 'F', 'C', 'B', 'A', 'A', 'D', 'C', 'D', 'A', 'A', 'B')
number_a = grades.count('A')
number_b = grades.count('B')
number_c = grades.count('C')
number_d = grades.count('D')
number_f = grades.count('F')
grades_count = [number_a, number_b, number_c, number_d, number_f]
print(grades_count)
# Out:
# [4, 4, 2, 2, 1]

# %%
x = eval(input('enter x coordinates: '))
y = eval(input('enter y coordinates: '))
within_dart = x**2 + y**2 < 100
print(within_dart)
# Out:
# enter x coordinates: -7
# enter y coordinates: 8
# False

# %%
import math
length = eval(input('Please enter ladder length: '))
angle = eval(input('Please enter ladder angle: '))
rad_angle = (math.pi * angle)/180
height = length * math.sin(rad_angle)
result = 'Your ladder height is ' + str(height) + 'feet'
print(result)
# Out:
# Please enter ladder length: 24
# Please enter ladder angle: 80
# Your ladder height is 23.63538607229299 feet

# %%
import math
lst = ['a', 'a', 'b', 'c', 'd', 'f', 'g', 'h']
middle_element_index = math.floor(len(lst)/2)
middle_element = lst[middle_element_index]
print(middle_element)
lst.sort()
lst.reverse()
print(lst)
first_element = lst[0]
lst.pop(0)
lst.append(first_element)
print(lst)
# Out:
# d
# ['h', 'g', 'f', 'd', 'c', 'b', 'a', 'a']
# ['g', 'f', 'd', 'c', 'b', 'a', 'a', 'h']

# %%
0==(1==2)
# Out:
# True

# %% [markdown]
# 5==True

# %%
5 == True
# Out:
# False

# %%
2 + (3 == 4) + 5 == 7
# Out:
# True

# %%
(1<-1) == (3>4)
# Out:
# True
